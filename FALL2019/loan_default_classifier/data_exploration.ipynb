# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\A Sua\\Documents\\FIU\\Fall2019\\ML\\project'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'application_test_data.xlsx',
#  'application_training_data.xlsx',
#  'application_training_data_import.csv',
#  'CAP 5610 - Project Rubric.docx',
#  'data_dictionary.csv',
#  'data_exploration.ipynb',
#  'home-credit-default-risk.zip',
#  'Project Proposal.docx',
#  'project_instructions.ipynb',
#  '~$oject Proposal.docx']

# %%
training_data= pd.read_csv('application_training_data_import.csv', index_col='SK_ID_CURR')
training_data.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE GENDER_FLAG  FLAG_OW0_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M             0
# 100003           0         Cash loans           F             0
# 100004           0    Revolving loans           M             1
# 100006           0         Cash loans           F             0
# 100007           0         Cash loans           M             0
#
#             FLAG_OW0_REALT1  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                    1             0          202500.0    406597.5
# 100003                    0             0          270000.0   1293502.5
# 100004                    1             0           67500.0    135000.0
# 100006                    1             0          135000.0    312682.5
# 100007                    1             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE  ... FLAG_DOCUMENT_18  \
# SK_ID_CURR                                ...
# ...
